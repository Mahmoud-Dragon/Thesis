# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use("seaborn")

# %%
df= pd.read_csv('/Users/DELL/Desktop/laptops_dataset.csv')
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
df.describe(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              977 non-null    object
#  1   Model Name                977 non-null    object
#  2   Category                  977 non-null    object
#  3   Screen Size               977 non-null    object
#  4   Screen                    977 non-null    object
#  5   CPU                       977 non-null    object
#  6   RAM                       977 non-null    object
#  7    Storage                  977 non-null    object
#  8   GPU                       977 non-null    object
#  9   Operating System          977 non-null    object
#  10  Operating System Version  841 non-null    object
#  11  Weight                    977 non-null    object
#  12  Price                     977 non-null    float64
# dtypes: float64(1), object(12)
# ...

# %%
df=df.drop(['Weight'],axis=1) #as the weight of the laptop doesnt affect the price

# %%
df['RAM']=df['RAM'].str.extract('(\d+)',expand=False) #to remove the GB sign
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8
# 1                            1440x900        Intel Core i5 1.8GHz   8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
df['Screen Size']=df['Screen Size'].str.extract('(\d+)',expand=False) #to remove the "
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook          13
# 1        Apple  Macbook Air  Ultrabook          13
# 2           HP       250 G6   Notebook          15
# 3        Apple  MacBook Pro  Ultrabook          15
# 4        Apple  MacBook Pro  Ultrabook          13
#
#                                Screen                         CPU RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8
# 1                            1440x900        Intel Core i5 1.8GHz   8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
df.tail()
# Out:
#     Manufacturer       Model Name  Category Screen Size  \
# 972         Dell     Alienware 17    Gaming          17
# 973      Toshiba  Tecra A40-C-1DF  Notebook          14
# 974         Asus        Rog Strix    Gaming          17
# 975           HP      Probook 450  Notebook          15
# 976       Lenovo    ThinkPad T460  Notebook          14
#
#                           Screen                          CPU RAM  \
# 972            Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz  32
# 973            Full HD 1920x1080   Intel Core i5 6200U 2.3GHz   8
# 974            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16
# 975  IPS Panel Full HD 1920x1080  Intel Core i5 7200U 2.70GHz   8
# 976                     1366x768   Intel Core i5 6200U 2.3GHz   4
#
#                   Storage                      GPU Operating System  \
# 972  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1070          Windows
# 973             256GB SSD    Intel HD Graphics 520          Windows
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              977 non-null    object
#  1   Model Name                977 non-null    object
#  2   Category                  977 non-null    object
#  3   Screen Size               977 non-null    object
#  4   Screen                    977 non-null    object
#  5   CPU                       977 non-null    object
#  6   RAM                       977 non-null    object
#  7    Storage                  977 non-null    object
#  8   GPU                       977 non-null    object
#  9   Operating System          977 non-null    object
#  10  Operating System Version  841 non-null    object
#  11  Price                     977 non-null    float64
# dtypes: float64(1), object(11)
# memory usage: 91.7+ KB

# %%
df['Screen Size']=df['Screen Size'].interpolate().astype(float) #adjust data type to float from object
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              977 non-null    object
#  1   Model Name                977 non-null    object
#  2   Category                  977 non-null    object
#  3   Screen Size               977 non-null    float64
#  4   Screen                    977 non-null    object
#  5   CPU                       977 non-null    object
#  6   RAM                       977 non-null    object
#  7    Storage                  977 non-null    object
#  8   GPU                       977 non-null    object
#  9   Operating System          977 non-null    object
#  10  Operating System Version  841 non-null    object
#  11  Price                     977 non-null    float64
# dtypes: float64(2), object(10)
# memory usage: 91.7+ KB

# %%
df.isnull().sum()
# Out:
# Manufacturer                  0
# Model Name                    0
# Category                      0
# Screen Size                   0
# Screen                        0
# CPU                           0
# RAM                           0
#  Storage                      0
# GPU                           0
# Operating System              0
# Operating System Version    136
# Price                         0
# dtype: int64

# %%
df['Operating System Version'].fillna(df['Operating System Version'].mode()[0], inplace=True)
df.head() # Replacing the Null Values with the mode
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.0
# 1        Apple  Macbook Air  Ultrabook         13.0
# 2           HP       250 G6   Notebook         15.0
# 3        Apple  MacBook Pro  Ultrabook         15.0
# 4        Apple  MacBook Pro  Ultrabook         13.0
#
#                                Screen                         CPU RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8
# 1                            1440x900        Intel Core i5 1.8GHz   8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
df['RAM']=df['RAM'].interpolate().astype(int) #adjust data type to int from object
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              977 non-null    object
#  1   Model Name                977 non-null    object
#  2   Category                  977 non-null    object
#  3   Screen Size               977 non-null    float64
#  4   Screen                    977 non-null    object
#  5   CPU                       977 non-null    object
#  6   RAM                       977 non-null    int32
#  7    Storage                  977 non-null    object
#  8   GPU                       977 non-null    object
#  9   Operating System          977 non-null    object
#  10  Operating System Version  977 non-null    object
#  11  Price                     977 non-null    float64
# dtypes: float64(2), int32(1), object(9)
# memory usage: 87.9+ KB

# %%
display(df.iloc[8])
# Out:
# Manufacturer                                      Asus
# Model Name                             ZenBook UX430UN
# Category                                     Ultrabook
# Screen Size                                       14.0
# Screen                               Full HD 1920x1080
# CPU                         Intel Core i7 8550U 1.8GHz
# RAM                                                 16
#  Storage                                     512GB SSD
# GPU                               Nvidia GeForce MX150
# Operating System                               Windows
# Operating System Version                            10
# Price                                       13293540.0
# Name: 8, dtype: object

# %%
sns.barplot(x=df['Manufacturer'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show() # Razer is the most expensive one

# %%
sns.barplot(x=df['RAM'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show() # The greater the RAM the more expensive the laptop

# %%
sns.barplot(x=df['Screen Size'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show() # The 18" screen is the most expensive laptop

# %%
# List of categorical variables to plot
cat_vars = ['Category','Operating System','Operating System Version','Screen',' Storage']

# Create figures with subplots
fig, axs = plt.subplots(nrows = 2, ncols = 4, figsize = (20,10))
axs = axs.flatten()

# create barplots for each categorical variable

for i, var in enumerate(cat_vars):
    sns.barplot(x = var, y = 'Price', data = df, ax = axs[i])
    axs[i].set_xticklabels(axs[i].get_xticklabels(),rotation = 90)
    

# adjust spacing between subplots

fig.tight_layout()

plt.show()

# %%
df['Category'].value_counts().plot(kind='bar') # the most present category of laptops is Notebook
# Out:
# <AxesSubplot:>

# %%
for col in df.columns:
    print(col)

    print(f'Number of unique values: {df[col].nunique()}\n')
# Out:
# Manufacturer
# Number of unique values: 19
#
# Model Name
# Number of unique values: 488
#
# Category
# Number of unique values: 6
#
# Screen Size
# Number of unique values: 8
#
# Screen
# Number of unique values: 38
#
# CPU
# Number of unique values: 106
#
# RAM
# Number of unique values: 8
#
#  Storage
# Number of unique values: 36
#
# GPU
# Number of unique values: 98
#
# Operating System
# Number of unique values: 7
#
# Operating System Version
# Number of unique values: 4
#
# Price
# Number of unique values: 639

# %%
df.describe()
# Out:
#        Screen Size         RAM         Price
# count   977.000000  977.000000  9.770000e+02
# mean     14.630502    8.528147  1.001899e+07
# std       1.373644    4.997487  6.306430e+06
# min      10.000000    2.000000  1.706375e+06
# 25%      14.000000    4.000000  5.326308e+06
# 50%      15.000000    8.000000  8.527428e+06
# 75%      15.000000    8.000000  1.311570e+07
# max      18.000000   32.000000  5.423231e+07

# %%
plt.hist(df['Price']) #histogram of price
# Out:
# (array([367., 330., 169.,  69.,  31.,   6.,   1.,   2.,   1.,   1.]),
#  array([ 1706374.8 ,  6958968.12, 12211561.44, 17464154.76, 22716748.08,
#         27969341.4 , 33221934.72, 38474528.04, 43727121.36, 48979714.68,
#         54232308.  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize = (18, 12))


plt.subplot(3, 2, 2)

sns.countplot(x = 'RAM', data = df)

plt.subplot(3, 2, 3)

sns.countplot(x = 'Operating System', data = df)

plt.subplot(3, 2, 4)

sns.countplot(x = 'Operating System Version', data = df)
#counts present of these columns in the dataframe
# Out:
# <AxesSubplot:xlabel='Operating System Version', ylabel='count'>

# %%
from sklearn.preprocessing import LabelEncoder
Cat = LabelEncoder()
df['Category'] = Cat.fit_transform(df['Category']) #encoding the column

# %%
from sklearn.preprocessing import LabelEncoder
Manu = LabelEncoder()
df['Manufacturer'] = Manu.fit_transform(df['Manufacturer'])#encoding the column

# %%
from sklearn.preprocessing import LabelEncoder
Mod = LabelEncoder()
df['Model Name'] = Mod.fit_transform(df['Model Name'])#encoding the column

# %%
from sklearn.preprocessing import LabelEncoder
Scree = LabelEncoder()
df['Screen'] = Scree.fit_transform(df['Screen'])#encoding the column

# %%
from sklearn.preprocessing import LabelEncoder
CP = LabelEncoder()
df['CPU'] = CP.fit_transform(df['CPU'])#encoding the column

# %%
from sklearn.preprocessing import LabelEncoder
GP = LabelEncoder()
df['GPU'] = GP.fit_transform(df['GPU'])#encoding the column

# %%
from sklearn.preprocessing import LabelEncoder
OS = LabelEncoder()
df['Operating System'] = OS.fit_transform(df['Operating System'])

# %%
from sklearn.preprocessing import LabelEncoder
OSV = LabelEncoder()
df['Operating System Version'] = OSV.fit_transform(df['Operating System Version'])

# %%
from sklearn.preprocessing import LabelEncoder
ST = LabelEncoder()
df[' Storage'] = ST.fit_transform(df[' Storage'])

# %%
df
# Out:
#      Manufacturer  Model Name  Category  Screen Size  Screen  CPU  RAM  \
# 0               1         236         4         13.0      23   58    8
# 1               1         237         4         13.0       1   56    8
# 2               7          38         3         15.0       8   67    8
# 3               1         236         4         15.0      25   77   16
# 4               1         236         4         13.0      23   60    8
# ..            ...         ...       ...          ...     ...  ...  ...
# 972             4          43         1         17.0       8   83   32
# 973            16         339         3         14.0       8   61    8
# 974             2         318         1         17.0       8   93   16
# 975             7         293         3         15.0      15   68    8
# 976            10         362         3         14.0       0   61    4
#
#       Storage  GPU  Operating System  Operating System Version        Price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              977 non-null    int32
#  1   Model Name                977 non-null    int32
#  2   Category                  977 non-null    int32
#  3   Screen Size               977 non-null    float64
#  4   Screen                    977 non-null    int32
#  5   CPU                       977 non-null    int32
#  6   RAM                       977 non-null    int32
#  7    Storage                  977 non-null    int32
#  8   GPU                       977 non-null    int32
#  9   Operating System          977 non-null    int32
#  10  Operating System Version  977 non-null    int32
#  11  Price                     977 non-null    float64
# dtypes: float64(2), int32(10)
# memory usage: 53.6 KB

# %%
plt.figure(figsize=(30,30))
sns.heatmap(df.corr(),annot=True,cmap='Reds')
#Plotting a heatmap to observe the correlation between variables
#The most correlated variable is RAM (0.76)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split #Splitting the data into training and testing data

d = df.drop('Price',axis=1) # Independent variables
e = df['Price'] # Dependent variable

# %%
d_train, d_test, e_train, e_test = train_test_split(d,e,test_size=0.2,random_state=23)

print('Training dataset size:', d_train.shape[0])
print('Testing dataset size:', d_test.shape[0])
# Out:
# Training dataset size: 781
# Testing dataset size: 196

# %%
from sklearn.tree import DecisionTreeRegressor,plot_tree
reg= DecisionTreeRegressor(criterion='squared_error',max_depth=4,min_samples_split=10,random_state=5)

# %%
reg.fit(d_train,e_train) #fitting the model on the training data
# Out:
# DecisionTreeRegressor(max_depth=4, min_samples_split=10, random_state=5)

# %%
y_pred= reg.predict(d_test) #predicting prices on the testing data

# %%
y_pred
# Out:
# array([ 9897529.59      ,  9897529.59      ,  9897529.59      ,
#         5796317.28      ,  3119723.0455814 ,  9897529.59      ,
#         9897529.59      , 12728901.952     ,  9897529.59      ,
#         9897529.59      ,  9897529.59      , 16583616.02793104,
#         9897529.59      ,  9897529.59      ,  9897529.59      ,
#         9897529.59      ,  9897529.59      ,  3119723.0455814 ,
#        12728901.952     ,  9897529.59      ,  9897529.59      ,
#         4379078.03478261, 39026988.        ,  9897529.59      ,
#         9897529.59      ,  5796317.28      , 16583616.02793104,
#        12728901.952     , 12728901.952     ,  4379078.03478261,
#         9897529.59      , 12728901.952     ,  9897529.59      ,
#         9897529.59      , 22428958.5       ,  9897529.59      ,
#         5796317.28      ,  5799186.72878049, 16583616.02793104,
#        12728901.952     , 10844683.2       ,  9897529.59      ,
#         9897529.59      ,  5799186.72878049,  5796317.28      ,
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score
r2_score(e_test,y_pred) #R2
# Out:
# 0.7485175699671865

# %%
rmse = mean_squared_error(y_pred, e_test, squared=False)

# %%
rmse
# Out:
# 3293466.050919613

# %%
y_pred= reg.predict(d_train)
y_pred
# Out:
# array([ 4379078.03478261,  3119723.0455814 , 12728901.952     ,
#         9897529.59      ,  9897529.59      , 16583616.02793104,
#        12728901.952     ,  9897529.59      , 17807156.25      ,
#         5796317.28      , 16583616.02793104,  5796317.28      ,
#         3119723.0455814 ,  4379078.03478261,  9897529.59      ,
#         9897529.59      ,  9897529.59      ,  5796317.28      ,
#         9897529.59      , 42349632.        , 10844683.2       ,
#         5796317.28      ,  9897529.59      , 17807156.25      ,
#         9897529.59      ,  9897529.59      ,  9897529.59      ,
#         5796317.28      ,  3119723.0455814 ,  9897529.59      ,
#        12728901.952     ,  9897529.59      , 16583616.02793104,
#         5799186.72878049,  9897529.59      ,  5796317.28      ,
#         9897529.59      , 16583616.02793104, 17807156.25      ,
#        16583616.02793104,  3119723.0455814 ,  3119723.0455814 ,
#         9897529.59      , 16583616.02793104,  5796317.28      ,
# ...

# %%
rmse1 = mean_squared_error(y_pred, e_train, squared=False)

# %%
rmse1
# Out:
# 3189163.321733692

# %%
mean_squared_error (e_test,y_pred) #mean squared error
# Out:
# 10846918628560.03

# %%
fig, axe = plt.subplots(figsize=(30,10),dpi=300)

plot_tree(reg, feature_names=d.columns, filled=True,
         class_names=['No', 'Yes'],rounded=True,ax=axe,fontsize=6);
           
plt.show() #drawing the tree

# %%
""""
import graphviz #visualize the tree
from sklearn.tree import export_graphviz
dot_data = export_graphviz(reg, out_file=None,
                           feature_names=d.columns,
                           class_names=['No', 'Yes'],
                           filled=True, rounded=True,
                           special_characters=True) 

graph = graphviz.Source(dot_data)

graph
""""
# Out:
#   File "C:\Users\DELL\AppData\Local\Temp\ipykernel_16336\2933751393.py", line 13
#     """"
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
from sklearn.model_selection import cross_val_score
#reg= DecisionTreeRegressor(criterion='squared_error',max_depth=6,min_samples_split=10,random_state=5)
scores=cross_val_score (reg,e_train,d_train,scoring='r2',cv=10)
scores
