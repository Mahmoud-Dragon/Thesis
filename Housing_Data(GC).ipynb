# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use("seaborn")
# Out:
# <ipython-input-66-c89f6c412c78>:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
path = "/content/drive/MyDrive/Dataset/House Price India.csv"
df= pd.read_csv(path)
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.describe(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
df['number of bathrooms'] = df['number of bathrooms'].astype('int') #Change Datatype to int

# %%
df['number of floors'] = df['number of floors'].astype('int') #Change Datatype to int

# %%
df.describe().T
# Out:
#                                          count          mean            std  \
# id                                     14620.0  6.762821e+09    6237.574799
# Date                                   14620.0  4.260454e+04      67.347991
# number of bedrooms                     14620.0  3.379343e+00       0.938719
# number of bathrooms                    14620.0  1.761286e+00       0.736921
# living area                            14620.0  2.098263e+03     928.275721
# lot area                               14620.0  1.509328e+04   37919.621304
# number of floors                       14620.0  1.453352e+00       0.552787
# waterfront present                     14620.0  7.660739e-03       0.087193
# number of views                        14620.0  2.331053e-01       0.766259
# condition of the house                 14620.0  3.430506e+00       0.664151
# grade of the house                     14620.0  7.682421e+00       1.175033
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  int64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  int64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
#  10  grade of the house                     14620 non-null  int64
# ...

# %%
#df=df.drop(['Postal Code'],axis=1) #as the postal code doesnt affect the price

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  int64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  int64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
#  10  grade of the house                     14620 non-null  int64
# ...

# %%
print(df['waterfront present'].value_counts()[0])
# Out:
# 14508

# %%
print(df['Renovation Year'].value_counts()[0])
# Out:
# 13954

# %%
df=df.drop(['waterfront present'],axis=1) #too much 0 rows

# %%
df=df.drop(['Renovation Year'],axis=1) #too much 0 rows

# %%
# displays box plot of each features

fig = plt.figure(figsize = [30, 18]) # defining entire figure size

for i in range(1, len(list(df.columns))):
    plt.subplot(8, 3, i) # makes subplot
    
    fig.tight_layout(pad=2) # gives space between the subplots
    df1 = df.iloc[:,i] # making new dataframe using slicing technique to remote the unwanted columns
    
    plt.suptitle('Comparision of all Features') # main title
    plt.title(list(df.columns)[i]) # title for each subplots
    
    sns.boxenplot(df1) # making box plot

plt.show()

# %%
for x in ['grade of the house']:
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan
    # The instances above q75+(1.5*intr_qr) or below q25-(1.5*intr_qr) are located and replaced by NaN

# %%
df.isnull().sum()
# Out:
# id                                          0
# Date                                        0
# number of bedrooms                          0
# number of bathrooms                         0
# living area                                 0
# lot area                                    0
# number of floors                            0
# number of views                             0
# condition of the house                      0
# grade of the house                       1320
# Area of the house(excluding basement)       0
# Area of the basement                        0
# Built Year                                  0
# Postal Code                                 0
# Lattitude                                   0
# Longitude                                   0
# living_area_renov                           0
# lot_area_renov                              0
# Number of schools nearby                    0
# Distance from the airport                   0
# ...

# %%
df = df.dropna(axis = 0)
#Dropping the Nulls

# %%
for x in ['living area']:
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan

    # The instances above q75+(1.5*intr_qr) or below q25-(1.5*intr_qr) are located and replaced by NaN

# %%
for x in ['number of bathrooms']:
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan

    # The instances above q75+(1.5*intr_qr) or below q25-(1.5*intr_qr) are located and replaced by NaN

# %%
for x in ['number of bedrooms']:
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan

    # The instances above q75+(1.5*intr_qr) or below q25-(1.5*intr_qr) are located and replaced by NaN

# %%
for x in ['Area of the basement']:
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan

    # The instances above q75+(1.5*intr_qr) or below q25-(1.5*intr_qr) are located and replaced by NaN

# %%
df.isnull().sum()
# Out:
# id                                         0
# Date                                       0
# number of bedrooms                       287
# number of bathrooms                       86
# living area                              163
# lot area                                   0
# number of floors                           0
# number of views                            0
# condition of the house                     0
# grade of the house                         0
# Area of the house(excluding basement)      0
# Area of the basement                     208
# Built Year                                 0
# Postal Code                                0
# Lattitude                                  0
# Longitude                                  0
# living_area_renov                          0
# lot_area_renov                             0
# Number of schools nearby                   0
# Distance from the airport                  0
# Price                                      0
# ...

# %%
df = df.dropna(axis = 0)
# We drop the nulls

# %%
plt.figure(figsize=(12,18))
sns.countplot(data=df,y='Built Year')
plt.show()
#most houses were sold in 2014

# %%
plt.figure(figsize=(30,30))
sns.heatmap(df.corr(),annot=True,cmap='Reds')
#Plotting a heatmap to observe the correlation between variables
# Out:
# <Axes: >

# %%
#it is most correlated with the living area

# %%
df=df.drop(['lot area','condition of the house','Built Year','lot_area_renov','Number of schools nearby','Distance from the airport','Longitude'],axis=1) #as the heatmap showed it had little to no relation with the price

# %%
#df=df.drop(['id'],axis=1) # the id of the buyer doesnt relate to price#

# %%
f = plt.figure(figsize=(14,6))
ax = f.add_subplot(121)
sns.scatterplot(x='living area', y='Price', data=df, palette='magma', ax=ax)
ax.set_title('Scatter Plot of Price vs Living Area')
# Out:
# <ipython-input-94-ea8eeacde8af>:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='living area', y='Price', data=df, palette='magma', ax=ax)
# Text(0.5, 1.0, 'Scatter Plot of Price vs Living Area')

# %%
sns.lmplot(x='living area', y='Price', data=df, palette='magma', height=8);

# living area is +ve correlated with price

# %%
f = plt.figure(figsize=(14,6))
ax = f.add_subplot(121)
sns.scatterplot(x='number of bedrooms', y='Price', data=df, palette='magma', ax=ax)
ax.set_title('Scatter Plot of Price vs bedrooms')
# Out:
# <ipython-input-96-d5c1a52c1a5c>:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='number of bedrooms', y='Price', data=df, palette='magma', ax=ax)
# Text(0.5, 1.0, 'Scatter Plot of Price vs bedrooms')

# %%
f = plt.figure(figsize=(14,6))
ax = f.add_subplot(121)
sns.scatterplot(x='number of bathrooms', y='Price', data=df, palette='magma', ax=ax)
ax.set_title('Scatter Plot of Price vs bathrooms')
# Out:
# <ipython-input-97-128b1c9a36b0>:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='number of bathrooms', y='Price', data=df, palette='magma', ax=ax)
# Text(0.5, 1.0, 'Scatter Plot of Price vs bathrooms')

# %%
sns.lmplot(x='number of bathrooms', y='Price', data=df, palette='magma', height=8);

# %%
sns.barplot(data=df,x='number of bathrooms',y='Price')
# +ve correlation between no of bathrooms and price
# Out:
# <Axes: xlabel='number of bathrooms', ylabel='Price'>

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 1      6762810635  42491                 4.0                  2.0
# 2      6762810998  42491                 5.0                  2.0
# 3      6762812605  42491                 4.0                  2.0
# 4      6762812919  42491                 3.0                  2.0
# 5      6762813105  42491                 3.0                  2.0
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                 2.0                  1.0
# 14616  6762830339  42734                 3.0                  2.0
# 14617  6762830618  42734                 2.0                  1.0
# 14618  6762830709  42734                 4.0                  1.0
# 14619  6762831463  42734                 3.0                  1.0
#
#        living area  number of floors  number of views  grade of the house  \
# 1           2920.0                 1                0                 8.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12702 entries, 1 to 14619
# Data columns (total 14 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     12702 non-null  int64
#  1   Date                                   12702 non-null  int64
#  2   number of bedrooms                     12702 non-null  float64
#  3   number of bathrooms                    12702 non-null  float64
#  4   living area                            12702 non-null  float64
#  5   number of floors                       12702 non-null  int64
#  6   number of views                        12702 non-null  int64
#  7   grade of the house                     12702 non-null  float64
#  8   Area of the house(excluding basement)  12702 non-null  int64
#  9   Area of the basement                   12702 non-null  float64
# ...

# %%
"""numerical_columns = ['number of bedrooms', 'number of bathrooms','number of floors','number of views','grade of the house',
'Area of the house(excluding basement)','Longitude','living_area_renov','lot_area_renov','Distance from the airport']


df[numerical_columns] = ( 
    
    df[numerical_columns] - df[numerical_columns].min()  
    
) /( 
    
    df[numerical_columns].max() - df[numerical_columns].min()
)


df.head() #Normalization
"""
# Out:
# "numerical_columns = ['number of bedrooms', 'number of bathrooms','number of floors','number of views','grade of the house',\n'Area of the house(excluding basement)','Longitude','living_area_renov','lot_area_renov','Distance from the airport']\n\n\ndf[numerical_columns] = ( \n    \n    df[numerical_columns] - df[numerical_columns].min()  \n    \n) /( \n    \n    df[numerical_columns].max() - df[numerical_columns].min()\n)\n\n\ndf.head() #Normalization\n"

# %%
from sklearn.model_selection import train_test_split

d = df.drop('Price',axis=1) # Independent variable
e = df['Price'] # Dependent variable

d_train, d_test, e_train, e_test = train_test_split(d,e,test_size=0.2,random_state=23)

print('Training dataset size:', d_train.shape[0])
print('Testing dataset size:', d_test.shape[0])

# splitting the dataset into 0.8 training data and 0.2 testing data
# Out:
# Training dataset size: 10161
# Testing dataset size: 2541

# %%
from sklearn.linear_model import LinearRegression


lm = LinearRegression()


lm.fit(d_train, e_train);
# fitting in the data in the model

# %%
parameter = ['theta_0'] + ['theta_{}'.format(i+1) for i in range(d.shape[1])]
columns = ['y-intersect'] + list(d.columns.values)
sk_theta = pd.Series([lm.intercept_] + list(lm.coef_))

parameter_df = pd.DataFrame({'parameter':parameter,'column':columns, 'theta_value': sk_theta})
parameter_df

# Creating the linear regression equation
# Out:
#    parameter                                 column   theta_value
# 0    theta_0                            y-intersect  2.379803e+11
# 1    theta_1                                     id -3.519945e+01
# 2    theta_2                                   Date  1.302876e+01
# 3    theta_3                     number of bedrooms -8.924389e+02
# 4    theta_4                    number of bathrooms  8.715806e+02
# 5    theta_5                            living area  5.365253e+00
# 6    theta_6                       number of floors -7.312254e+03
# 7    theta_7                        number of views  2.174319e+04
# 8    theta_8                     grade of the house  3.632674e+03
# 9    theta_9  Area of the house(excluding basement)  3.289681e+00
# 10  theta_10                   Area of the basement  2.075572e+00
# 11  theta_11                            Postal Code  5.757453e+02
# 12  theta_12                              Lattitude -5.826132e+04
# ...

# %%
y_pred = lm.predict(d_test)

# Evaluation
from sklearn.metrics import mean_squared_error
rmse = mean_squared_error(y_pred, e_test, squared=False)

# R_square
R_square = lm.score(d_test,e_test)
print('The root mean square error (RMSE) is: ', rmse)
print('R^2 obtained is:', R_square)
# Out:
# The root mean square error (RMSE) is:  88186.28841778035
# R^2 obtained is: 0.8434480922369941

# %%
e_test.mean()
# Out:
# 474472.95867768594

# %%
y_pred.mean()
# Out:
# 475055.98766730743

# %%
y_pred
# Out:
# array([122052.94314575, 568936.3878479 , 346192.21447754, ...,
#        712072.40893555, 316561.49798584, 415135.53408813])

# %%
plt.scatter(y_pred, e_test, color='blue', marker='o')

plt.plot(e_test, e_test, color="red", lw=1.5)
plt.title("LinearRegressor")
plt.xlabel('independent variables')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

lm = LinearRegression()
scores= cross_val_score(lm,d_train,e_train,scoring='r2',cv=10)
scores
#Cross Validation with 20 folds
# Out:
# array([0.88211043, 0.86659457, 0.88153092, 0.856919  , 0.89349254,
#        0.85369947, 0.82833022, 0.8408962 , 0.86330404, 0.82745193])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

lm = LinearRegression()
scores2= cross_val_score(lm,d_train,e_train,scoring='median_absolute_error',cv=10)
scores2
#Cross Validation with 20 folds

# %%
lm1 = LinearRegression()
scores1= cross_val_score(lm,d_train,e_train,scoring='neg_root_mean_squared_error',cv=10)
scores1
#Cross Validation with 10 folds
# Out:
# array([-73922.10854053, -83540.34163708, -72829.58514976, -86253.98783991,
#        -65832.46004319, -82562.30775039, -98151.31772138, -89520.0003886 ,
#        -82047.84019572, -96610.33067477])
